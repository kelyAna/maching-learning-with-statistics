# %% [markdown]
# # Regressão Linear - Predição da Idade

# %% [markdown]
# ### importar bibliotecas

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### ler train.csv e test.csv

# %%
train = pd.read_csv('titanic/train.csv')

# %%
test = pd.read_csv('titanic/test.csv')

# %% [markdown]
# ### transformar definir o Id do Passageiro como Index

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train.set_index('PassengerId', inplace=True)

# %%
test.set_index('PassengerId', inplace=True)

# %% [markdown]
# ### Verificar shape dos dois

# %%
train.shape, test.shape
# Out:
# ((891, 11), (418, 10))

# %% [markdown]
# ### Criar coluna "Survived" no test set

# %%
test['Survived'] = np.nan

# %%
test['Survived']
# Out:
# PassengerId
# 892    NaN
# 893    NaN
# 894    NaN
# 895    NaN
# 896    NaN
# 897    NaN
# 898    NaN
# 899    NaN
# 900    NaN
# 901    NaN
# 902    NaN
# 903    NaN
# 904    NaN
# 905    NaN
# 906    NaN
# 907    NaN
# 908    NaN
# 909    NaN
# 910    NaN
# 911    NaN
# 912    NaN
# 913    NaN
# 914    NaN
# 915    NaN
# 916    NaN
# 917    NaN
# 918    NaN
# 919    NaN
# 920    NaN
# 921    NaN
#         ..
# 1280   NaN
# 1281   NaN
# 1282   NaN
# 1283   NaN
# 1284   NaN
# 1285   NaN
# 1286   NaN
# 1287   NaN
# 1288   NaN
# 1289   NaN
# 1290   NaN
# 1291   NaN
# 1292   NaN
# 1293   NaN
# 1294   NaN
# 1295   NaN
# 1296   NaN
# 1297   NaN
# 1298   NaN
# 1299   NaN
# 1300   NaN
# 1301   NaN
# 1302   NaN
# 1303   NaN
# 1304   NaN
# 1305   NaN
# 1306   NaN
# 1307   NaN
# 1308   NaN
# 1309   NaN
# Name: Survived, Length: 418, dtype: float64

# %% [markdown]
# ### Concatenar train e test set

# %%
data = pd.concat([train, test], sort=False)

# %%
data.shape
# Out:
# (1309, 11)

# %% [markdown]
# ### Traduzir colunas

# %%
data.columns
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket',
#        'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
data.columns = ['Sobreviveu', 'Classe', 'Nome', 'Sexo', 'Idade',
                'IrmaosConjuge', 'PaisFilhos', 'Bilhete','Tarifa', 'Cabine', 'Embarque']

# %% [markdown]
# ### Traduzir Sexo

# %%
data.head()
# Out:
#              Sobreviveu  Classe  \
# PassengerId
# 1                   0.0       3
# 2                   1.0       1
# 3                   1.0       3
# 4                   1.0       1
# 5                   0.0       3
#
#                                                           Nome    Sexo  Idade  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male   22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38.0
# 3                                       Heikkinen, Miss. Laina  female   26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35.0
# 5                                     Allen, Mr. William Henry    male   35.0
#
#              IrmaosConjuge  PaisFilhos           Bilhete   Tarifa Cabine  \
# PassengerId
# 1                        1           0         A/5 21171   7.2500    NaN
# 2                        1           0          PC 17599  71.2833    C85
# 3                        0           0  STON/O2. 3101282   7.9250    NaN
# 4                        1           0            113803  53.1000   C123
# 5                        0           0            373450   8.0500    NaN
#
#             Embarque
# PassengerId
# 1                  S
# 2                  C
# 3                  S
# 4                  S
# 5                  S

# %%
data['Sexo'] = data['Sexo'].map({'male':'homem', 'female': 'mulher'})

# %%
data.head()
# Out:
#              Sobreviveu  Classe  \
# PassengerId
# 1                   0.0       3
# 2                   1.0       1
# 3                   1.0       3
# 4                   1.0       1
# 5                   0.0       3
#
#                                                           Nome    Sexo  Idade  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris   homem   22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  mulher   38.0
# 3                                       Heikkinen, Miss. Laina  mulher   26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  mulher   35.0
# 5                                     Allen, Mr. William Henry   homem   35.0
#
#              IrmaosConjuge  PaisFilhos           Bilhete   Tarifa Cabine  \
# PassengerId
# 1                        1           0         A/5 21171   7.2500    NaN
# 2                        1           0          PC 17599  71.2833    C85
# 3                        0           0  STON/O2. 3101282   7.9250    NaN
# 4                        1           0            113803  53.1000   C123
# 5                        0           0            373450   8.0500    NaN
#
#             Embarque
# PassengerId
# 1                  S
# 2                  C
# 3                  S
# 4                  S
# 5                  S

# %% [markdown]
# ### Averiguar dados nulos

# %%
data.isnull().sum()
# Out:
# Sobreviveu        418
# Classe              0
# Nome                0
# Sexo                0
# Idade             263
# IrmaosConjuge       0
# PaisFilhos          0
# Bilhete             0
# Tarifa              1
# Cabine           1014
# Embarque            2
# dtype: int64

# %% [markdown]
# ### Remover Cabine

# %%
data.drop(columns=['Cabine'], inplace=True)

# %%
data.head()
# Out:
#              Sobreviveu  Classe  \
# PassengerId
# 1                   0.0       3
# 2                   1.0       1
# 3                   1.0       3
# 4                   1.0       1
# 5                   0.0       3
#
#                                                           Nome    Sexo  Idade  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris   homem   22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  mulher   38.0
# 3                                       Heikkinen, Miss. Laina  mulher   26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  mulher   35.0
# 5                                     Allen, Mr. William Henry   homem   35.0
#
#              IrmaosConjuge  PaisFilhos           Bilhete   Tarifa Embarque
# PassengerId
# 1                        1           0         A/5 21171   7.2500        S
# 2                        1           0          PC 17599  71.2833        C
# 3                        0           0  STON/O2. 3101282   7.9250        S
# 4                        1           0            113803  53.1000        S
# 5                        0           0            373450   8.0500        S

# %% [markdown]
# ### Checar dados nulos novamente

# %%
data.isnull().sum()
# Out:
# Sobreviveu       418
# Classe             0
# Nome               0
# Sexo               0
# Idade            263
# IrmaosConjuge      0
# PaisFilhos         0
# Bilhete            0
# Tarifa             1
# Embarque           2
# dtype: int64

# %% [markdown]
# ### Preencher dados nulos de "Embarque" com a moda

# %%
data['Embarque'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
moda = data['Embarque'].mode()[0]

# %%
data['Embarque'].fillna(moda, inplace=True)

# %% [markdown]
# ### Checar dados nulos novamente

# %%
data.isnull().sum()
# Out:
# Sobreviveu       418
# Classe             0
# Nome               0
# Sexo               0
# Idade            263
# IrmaosConjuge      0
# PaisFilhos         0
# Bilhete            0
# Tarifa             1
# Embarque           0
# dtype: int64

# %% [markdown]
# ### Preencher "Tarifa" faltando com a média

# %%
media_tarifa = data['Tarifa'].mean()

# %%
data['Tarifa'].fillna(media_tarifa, inplace=True)

# %% [markdown]
# ### Checar dados nulos

# %%
data.isnull().sum()
# Out:
# Sobreviveu       418
# Classe             0
# Nome               0
# Sexo               0
# Idade            263
# IrmaosConjuge      0
# PaisFilhos         0
# Bilhete            0
# Tarifa             0
# Embarque           0
# dtype: int64

# %% [markdown]
# ### Verificar correlações

# %%
data.corr()
# Out:
#                Sobreviveu    Classe     Idade  IrmaosConjuge  PaisFilhos  \
# Sobreviveu       1.000000 -0.338481 -0.077221      -0.035322    0.081629
# Classe          -0.338481  1.000000 -0.408106       0.060832    0.018322
# Idade           -0.077221 -0.408106  1.000000      -0.243699   -0.150917
# IrmaosConjuge   -0.035322  0.060832 -0.243699       1.000000    0.373587
# PaisFilhos       0.081629  0.018322 -0.150917       0.373587    1.000000
# Tarifa           0.257307 -0.558477  0.178229       0.160224    0.221522
#
#                  Tarifa
# Sobreviveu     0.257307
# Classe        -0.558477
# Idade          0.178229
# IrmaosConjuge  0.160224
# PaisFilhos     0.221522
# Tarifa         1.000000

# %% [markdown]
# ### Visualizar correlações com "heatmap"

# %%
sns.heatmap(data.corr(), annot=True, cmap='OrRd')

# %% [markdown]
# ### Remover coluna "Sobreviveu"
# Aparentemente não tem muita correlação com Idade, e está faltando bastante dados

# %%
data.drop(columns=['Sobreviveu'], inplace=True)

# %% [markdown]
# ### Checar dados nulos

# %%
data.isnull().sum()
# Out:
# Classe             0
# Nome               0
# Sexo               0
# Idade            263
# IrmaosConjuge      0
# PaisFilhos         0
# Bilhete            0
# Tarifa             0
# Embarque           0
# dtype: int64

# %% [markdown]
# # Engenharia de Recursos I

# %% [markdown]
# ### Criar coluna "Titulo" baseando-se na coluna "Nome"

# %%
data['Titulo'] = data['Nome'].str.extract('([a-zA-z]+)\.')

# %%
data['Titulo'].unique()
# Out:
# array(['Mr', 'Mrs', 'Miss', 'Master', 'Don', 'Rev', 'Dr', 'Mme', 'Ms',
#        'Major', 'Lady', 'Sir', 'Mlle', 'Col', 'Capt', 'Countess',
#        'Jonkheer', 'Dona'], dtype=object)

# %%
pd.crosstab(data['Titulo'], data['Sexo'])
# Out:
# Sexo      homem  mulher
# Titulo
# Capt          1       0
# Col           4       0
# Countess      0       1
# Don           1       0
# Dona          0       1
# Dr            7       1
# Jonkheer      1       0
# Lady          0       1
# Major         2       0
# Master       61       0
# Miss          0     260
# Mlle          0       2
# Mme           0       1
# Mr          757       0
# Mrs           0     197
# Ms            0       2
# Rev           8       0
# Sir           1       0

# %%
data['Titulo'] = data['Titulo'].apply(lambda x: 'Outros' if x not in ['Miss', 'Master', 'Mr', 'Mrs'] else x)

# %%
pd.crosstab(data['Titulo'], data['Sexo'])
# Out:
# Sexo    homem  mulher
# Titulo
# Master     61       0
# Miss        0     260
# Mr        757       0
# Mrs         0     197
# Outros     25       9

# %% [markdown]
# ### Traduzir "Titulos"

# %%
data.loc[data['Titulo']=='Master']
# Out:
#              Classe                                               Nome   Sexo  \
# PassengerId
# 8                 3                     Palsson, Master. Gosta Leonard  homem
# 17                3                               Rice, Master. Eugene  homem
# 51                3                         Panula, Master. Juha Niilo  homem
# 60                3                 Goodwin, Master. William Frederick  homem
# 64                3                              Skoog, Master. Harald  homem
# 66                3                           Moubarek, Master. Gerios  homem
# 79                2                      Caldwell, Master. Alden Gates  homem
# 126               3                       Nicola-Yarred, Master. Elias  homem
# 160               3                         Sage, Master. Thomas Henry  homem
# 165               3                       Panula, Master. Eino Viljami  homem
# 166               3    Goldsmith, Master. Frank John William "Frankie"  homem
# 172               3                               Rice, Master. Arthur  homem
# 177               3                      Lefebre, Master. Henry Forbes  homem
# 183               3              Asplund, Master. Clarence Gustaf Hugo  homem
# 184               2                          Becker, Master. Richard F  homem
# 194               2                         Navratil, Master. Michel M  homem
# 262               3                  Asplund, Master. Edvin Rojj Felix  homem
# 279               3                                 Rice, Master. Eric  homem
# 306               1                     Allison, Master. Hudson Trevor  homem
# 341               2                     Navratil, Master. Edmond Roger  homem
# 349               3             Coutts, Master. William Loch "William"  homem
# 387               3                    Goodwin, Master. Sidney Leonard  homem
# 408               2                     Richards, Master. William Rowe  homem
# 446               1                          Dodge, Master. Washington  homem
# 481               3                     Goodwin, Master. Harold Victor  homem
# 490               3              Coutts, Master. Eden Leslie "Neville"  homem
# 550               2                     Davies, Master. John Morgan Jr  homem
# 710               3  Moubarek, Master. Halim Gonios ("William George")  homem
# 752               3                                Moor, Master. Meier  homem
# 756               2                          Hamalainen, Master. Viljo  homem
# ...             ...                                                ...    ...
# 789               3                         Dean, Master. Bertram Vere  homem
# 803               1                Carter, Master. William Thornton II  homem
# 804               3                    Thomas, Master. Assad Alexander  homem
# 820               3                       Skoog, Master. Karl Thorsten  homem
# 825               3                       Panula, Master. Urho Abraham  homem
# 828               2                              Mallet, Master. Andre  homem
# 832               2                    Richards, Master. George Sibley  homem
# 851               3            Andersson, Master. Sigvard Harald Elias  homem
# 870               3                    Johnson, Master. Harold Theodor  homem
# 913               3                          Olsen, Master. Artur Karl  homem
# 947               3                               Rice, Master. Albert  homem
# 956               1                        Ryerson, Master. John Borie  homem
# 972               3                               Boulos, Master. Akar  homem
# 981               2                        Wells, Master. Ralph Lester  homem
# 1046              3                       Asplund, Master. Filip Oscar  homem
# 1053              3                     Touma, Master. Georges Youssef  homem
# 1084              3                  van Billiard, Master. Walter John  homem
# 1086              2                      Drew, Master. Marshall Brines  homem
# 1088              1                    Spedden, Master. Robert Douglas  homem
# 1093              3            Danbom, Master. Gilbert Sigvard Emanuel  homem
# 1136              3          Johnston, Master. William Arthur Willie""  homem
# 1173              3                     Peacock, Master. Alfred Edward  homem
# 1199              3                          Aks, Master. Philip Frank  homem
# 1231              3                              Betros, Master. Seman  homem
# 1236              3                van Billiard, Master. James William  homem
# 1252              3                        Sage, Master. William Henry  homem
# 1271              3                        Asplund, Master. Carl Edgar  homem
# 1281              3                        Palsson, Master. Paul Folke  homem
# 1284              3                      Abbott, Master. Eugene Joseph  homem
# 1309              3                           Peter, Master. Michael J  homem
#
#              Idade  IrmaosConjuge  PaisFilhos             Bilhete    Tarifa  \
# PassengerId
# 8             2.00              3           1              349909   21.0750
# 17            2.00              4           1              382652   29.1250
# 51            7.00              4           1             3101295   39.6875
# 60           11.00              5           2             CA 2144   46.9000
# 64            4.00              3           2              347088   27.9000
# 66             NaN              1           1                2661   15.2458
# 79            0.83              0           2              248738   29.0000
# 126          12.00              1           0                2651   11.2417
# 160            NaN              8           2            CA. 2343   69.5500
# 165           1.00              4           1             3101295   39.6875
# 166           9.00              0           2              363291   20.5250
# 172           4.00              4           1              382652   29.1250
# 177            NaN              3           1                4133   25.4667
# 183           9.00              4           2              347077   31.3875
# 184           1.00              2           1              230136   39.0000
# 194           3.00              1           1              230080   26.0000
# 262           3.00              4           2              347077   31.3875
# 279           7.00              4           1              382652   29.1250
# 306           0.92              1           2              113781  151.5500
# 341           2.00              1           1              230080   26.0000
# 349           3.00              1           1          C.A. 37671   15.9000
# 387           1.00              5           2             CA 2144   46.9000
# 408           3.00              1           1               29106   18.7500
# 446           4.00              0           2               33638   81.8583
# 481           9.00              5           2             CA 2144   46.9000
# 490           9.00              1           1          C.A. 37671   15.9000
# 550           8.00              1           1          C.A. 33112   36.7500
# 710            NaN              1           1                2661   15.2458
# 752           6.00              0           1              392096   12.4750
# 756           0.67              1           1              250649   14.5000
# ...            ...            ...         ...                 ...       ...
# 789           1.00              1           2           C.A. 2315   20.5750
# 803          11.00              1           2              113760  120.0000
# 804           0.42              0           1                2625    8.5167
# 820          10.00              3           2              347088   27.9000
# 825           2.00              4           1             3101295   39.6875
# 828           1.00              0           2     S.C./PARIS 2079   37.0042
# 832           0.83              1           1               29106   18.7500
# 851           4.00              4           2              347082   31.2750
# 870           4.00              1           1              347742   11.1333
# 913           9.00              0           1             C 17368    3.1708
# 947          10.00              4           1              382652   29.1250
# 956          13.00              2           2            PC 17608  262.3750
# 972           6.00              1           1                2678   15.2458
# 981           2.00              1           1               29103   23.0000
# 1046         13.00              4           2              347077   31.3875
# 1053          7.00              1           1                2650   15.2458
# 1084         11.50              1           1            A/5. 851   14.5000
# 1086          8.00              0           2               28220   32.5000
# 1088          6.00              0           2               16966  134.5000
# 1093          0.33              0           2              347080   14.4000
# 1136           NaN              1           2          W./C. 6607   23.4500
# 1173          0.75              1           1  SOTON/O.Q. 3101315   13.7750
# 1199          0.83              0           1              392091    9.3500
# 1231           NaN              0           0                2622    7.2292
# 1236           NaN              1           1            A/5. 851   14.5000
# 1252         14.50              8           2            CA. 2343   69.5500
# 1271          5.00              4           2              347077   31.3875
# 1281          6.00              3           1              349909   21.0750
# 1284         13.00              0           2           C.A. 2673   20.2500
# 1309           NaN              1           1                2668   22.3583
#
#             Embarque  Titulo
# PassengerId
# 8                  S  Master
# 17                 Q  Master
# 51                 S  Master
# 60                 S  Master
# 64                 S  Master
# 66                 C  Master
# 79                 S  Master
# 126                C  Master
# 160                S  Master
# 165                S  Master
# 166                S  Master
# 172                Q  Master
# 177                S  Master
# 183                S  Master
# 184                S  Master
# 194                S  Master
# 262                S  Master
# 279                Q  Master
# 306                S  Master
# 341                S  Master
# 349                S  Master
# 387                S  Master
# 408                S  Master
# 446                S  Master
# 481                S  Master
# 490                S  Master
# 550                S  Master
# 710                C  Master
# 752                S  Master
# 756                S  Master
# ...              ...     ...
# 789                S  Master
# 803                S  Master
# 804                C  Master
# 820                S  Master
# 825                S  Master
# 828                C  Master
# 832                S  Master
# 851                S  Master
# 870                S  Master
# 913                S  Master
# 947                Q  Master
# 956                C  Master
# 972                C  Master
# 981                S  Master
# 1046               S  Master
# 1053               C  Master
# 1084               S  Master
# 1086               S  Master
# 1088               C  Master
# 1093               S  Master
# 1136               S  Master
# 1173               S  Master
# 1199               S  Master
# 1231               C  Master
# 1236               S  Master
# 1252               S  Master
# 1271               S  Master
# 1281               S  Master
# 1284               S  Master
# 1309               C  Master
#
# [61 rows x 10 columns]

# %%
titulos_traduzidos = {
    'Master': 'Menino',
    'Miss': 'Solteira',
    'Mr': 'HomemAdulto',
    'Mrs': 'Casada'
}

# %%
data['Titulo'] = data['Titulo'].map(titulos_traduzidos)

# %%
data['Titulo']
# Out:
# PassengerId
# 1       HomemAdulto
# 2            Casada
# 3          Solteira
# 4            Casada
# 5       HomemAdulto
# 6       HomemAdulto
# 7       HomemAdulto
# 8            Menino
# 9            Casada
# 10           Casada
# 11         Solteira
# 12         Solteira
# 13      HomemAdulto
# 14      HomemAdulto
# 15         Solteira
# 16           Casada
# 17           Menino
# 18      HomemAdulto
# 19           Casada
# 20           Casada
# 21      HomemAdulto
# 22      HomemAdulto
# 23         Solteira
# 24      HomemAdulto
# 25         Solteira
# 26           Casada
# 27      HomemAdulto
# 28      HomemAdulto
# 29         Solteira
# 30      HomemAdulto
#            ...
# 1280    HomemAdulto
# 1281         Menino
# 1282    HomemAdulto
# 1283         Casada
# 1284         Menino
# 1285    HomemAdulto
# 1286    HomemAdulto
# 1287         Casada
# 1288    HomemAdulto
# 1289         Casada
# 1290    HomemAdulto
# 1291    HomemAdulto
# 1292       Solteira
# 1293    HomemAdulto
# 1294       Solteira
# 1295    HomemAdulto
# 1296    HomemAdulto
# 1297    HomemAdulto
# 1298    HomemAdulto
# 1299    HomemAdulto
# 1300       Solteira
# 1301       Solteira
# 1302       Solteira
# 1303         Casada
# 1304       Solteira
# 1305    HomemAdulto
# 1306            NaN
# 1307    HomemAdulto
# 1308    HomemAdulto
# 1309         Menino
# Name: Titulo, Length: 1309, dtype: object

# %% [markdown]
# ### Averiguar informações do DataFrame

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 1 to 1309
# Data columns (total 10 columns):
# Classe           1309 non-null int64
# Nome             1309 non-null object
# Sexo             1309 non-null object
# Idade            1046 non-null float64
# IrmaosConjuge    1309 non-null int64
# PaisFilhos       1309 non-null int64
# Bilhete          1309 non-null object
# Tarifa           1309 non-null float64
# Embarque         1309 non-null object
# Titulo           1275 non-null object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 112.5+ KB

# %% [markdown]
# ### Remover "Bilhete" e "Nome"

# %%
data.drop(columns=['Bilhete', 'Nome'], inplace=True)

# %%
data.head()
# Out:
#              Classe    Sexo  Idade  IrmaosConjuge  PaisFilhos   Tarifa  \
# PassengerId
# 1                 3   homem   22.0              1           0   7.2500
# 2                 1  mulher   38.0              1           0  71.2833
# 3                 3  mulher   26.0              0           0   7.9250
# 4                 1  mulher   35.0              1           0  53.1000
# 5                 3   homem   35.0              0           0   8.0500
#
#             Embarque       Titulo
# PassengerId
# 1                  S  HomemAdulto
# 2                  C       Casada
# 3                  S     Solteira
# 4                  S       Casada
# 5                  S  HomemAdulto

# %% [markdown]
# # Engenharia de Recursos II

# %% [markdown]
# ### Estudar possibilidade de identificar "meninas" similar aos "meninos"
# Através da combinação: "solteira" e está com "pais"

# %%
solteiras_com_pais = data.loc[(data['Titulo'] == 'Solteira') & (data['PaisFilhos']>=1)]

# %%
solteiras_com_pais.head()
# Out:
#              Classe    Sexo  Idade  IrmaosConjuge  PaisFilhos   Tarifa  \
# PassengerId
# 11                3  mulher    4.0              1           1  16.7000
# 25                3  mulher    8.0              3           1  21.0750
# 44                2  mulher    3.0              1           2  41.5792
# 59                2  mulher    5.0              1           2  27.7500
# 69                3  mulher   17.0              4           2   7.9250
#
#             Embarque    Titulo
# PassengerId
# 11                 S  Solteira
# 25                 S  Solteira
# 44                 C  Solteira
# 59                 S  Solteira
# 69                 S  Solteira

# %% [markdown]
# ### idade média de "meninas solteiras acompanhadas dos pais"

# %%
solteiras_com_pais['Idade'].mean()
# Out:
# 12.178815789473683

# %% [markdown]
# ### verificar distribuição da idade

# %%
plt.hist(solteiras_com_pais['Idade'], bins=15)
plt.show()

# %% [markdown]
# ### Média de mulheres "solteiras"

# %%
data.loc[data['Titulo']=='Solteira']['Idade'].mean()
# Out:
# 21.774238095238097

# %% [markdown]
# ### Distribuição das idades de mulheres "solteiras"

# %%
plt.hist(data.loc[data['Titulo']=='Solteira']['Idade'],bins=15)
plt.show()

# %% [markdown]
# ### Média de idade de mulheres "casadas"

# %%
data.loc[data['Titulo']=='Casada']['Idade'].mean()
# Out:
# 36.99411764705882

# %% [markdown]
# ### Distribuição das idades de mulheres "casadas"

# %%
plt.hist(data.loc[data['Titulo']=='Casada']['Idade'],bins=15)
plt.show()

# %% [markdown]
# ### Adicionar coluna "solteira com pais"

# %%
solteiras_com_pais.index
# Out:
# Int64Index([  11,   25,   44,   59,   69,   72,   89,  120,  129,  137,  148,
#              173,  181,  185,  206,  230,  234,  238,  298,  312,  319,  330,
#              342,  357,  375,  382,  410,  418,  420,  436,  437,  447,  449,
#              470,  480,  486,  531,  536,  540,  541,  542,  543,  581,  586,
#              594,  616,  619,  635,  643,  645,  652,  690,  692,  703,  721,
#              743,  751,  793,  814,  836,  853,  854,  864,  889,  918,  944,
#              945, 1009, 1017, 1032, 1067, 1078, 1080, 1095, 1106, 1130, 1142,
#             1155, 1175, 1176, 1188, 1218, 1246, 1277, 1294, 1301],
#            dtype='int64', name='PassengerId')

# %%
data['solteira_com_pais'] = 0

# %%
for idx, _ in data.iterrows():
    if idx in solteiras_com_pais.index:
        data['solteira_com_pais'].at[idx] = 1

# %%
data.loc[data['solteira_com_pais']==1]['Idade'].mean()
# Out:
# 12.178815789473683

# %%
data.loc[data['solteira_com_pais']==0]['Idade'].mean()
# Out:
# 31.26812371134021

# %% [markdown]
# ### Transformar recursos categóricos em "dummies"

# %%
data['Sexo'] = data['Sexo'].map({'homem':0, 'mulher':1})

# %%
data = pd.get_dummies(data, columns=['Classe', 'Embarque','Titulo'],drop_first=True)

# %%
data.head()
# Out:
#              Sexo  Idade  IrmaosConjuge  PaisFilhos   Tarifa  \
# PassengerId
# 1               0   22.0              1           0   7.2500
# 2               1   38.0              1           0  71.2833
# 3               1   26.0              0           0   7.9250
# 4               1   35.0              1           0  53.1000
# 5               0   35.0              0           0   8.0500
#
#              solteira_com_pais  Classe_2  Classe_3  Embarque_Q  Embarque_S  \
# PassengerId
# 1                            0         0         1           0           1
# 2                            0         0         0           0           0
# 3                            0         0         1           0           1
# 4                            0         0         0           0           1
# 5                            0         0         1           0           1
#
#              Titulo_HomemAdulto  Titulo_Menino  Titulo_Solteira
# PassengerId
# 1                             1              0                0
# 2                             0              0                0
# 3                             0              0                1
# 4                             0              0                0
# 5                             1              0                0

# %%
data.shape
# Out:
# (1309, 13)

# %% [markdown]
# ### Separar train e test para idades
# * treinar com dados não nulos
# * aplicar modelo em dados nulos

# %%
data.isnull().sum()
# Out:
# Sexo                    0
# Idade                 263
# IrmaosConjuge           0
# PaisFilhos              0
# Tarifa                  0
# solteira_com_pais       0
# Classe_2                0
# Classe_3                0
# Embarque_Q              0
# Embarque_S              0
# Titulo_HomemAdulto      0
# Titulo_Menino           0
# Titulo_Solteira         0
# dtype: int64

# %%
train_idade = data.dropna()

# %%
test_idade = data.loc[data['Idade'].isnull()].drop('Idade',axis=1)

# %%
test_idade
# Out:
#              Sexo  IrmaosConjuge  PaisFilhos    Tarifa  solteira_com_pais  \
# PassengerId
# 6               0              0           0    8.4583                  0
# 18              0              0           0   13.0000                  0
# 20              1              0           0    7.2250                  0
# 27              0              0           0    7.2250                  0
# 29              1              0           0    7.8792                  0
# 30              0              0           0    7.8958                  0
# 32              1              1           0  146.5208                  0
# 33              1              0           0    7.7500                  0
# 37              0              0           0    7.2292                  0
# 43              0              0           0    7.8958                  0
# 46              0              0           0    8.0500                  0
# 47              0              1           0   15.5000                  0
# 48              1              0           0    7.7500                  0
# 49              0              2           0   21.6792                  0
# 56              0              0           0   35.5000                  0
# 65              0              0           0   27.7208                  0
# 66              0              1           1   15.2458                  0
# 77              0              0           0    7.8958                  0
# 78              0              0           0    8.0500                  0
# 83              1              0           0    7.7875                  0
# 88              0              0           0    8.0500                  0
# 96              0              0           0    8.0500                  0
# 102             0              0           0    7.8958                  0
# 108             0              0           0    7.7750                  0
# 110             1              1           0   24.1500                  0
# 122             0              0           0    8.0500                  0
# 127             0              0           0    7.7500                  0
# 129             1              1           1   22.3583                  1
# 1294                0         0           0           0                   0
# 1295                0         0           0           1                   1
# 1296                0         0           0           0                   1
# 1297                1         0           0           0                   1
# 1298                1         0           0           1                   1
# 1299                0         0           0           0                   1
# 1301                0         1           0           1                   0
# 1303                0         0           1           0                   0
# 1304                0         1           0           1                   0
# 1306                0         0           0           0                   0
# 1307                0         1           0           1                   1
#
#              Titulo_Menino  Titulo_Solteira
# PassengerId
# 1                        0                0
# 2                        0                0
# 3                        0                1
# 4                        0                0
# 5                        0                0
# 7                        0                0
# 8                        1                0
# 9                        0                0
# 10                       0                0
# 11                       0                1
# 12                       0                1
# 13                       0                0
# 14                       0                0
# 15                       0                1
# 16                       0                0
# 17                       1                0
# 19                       0                0
# 21                       0                0
# 22                       0                0
# 23                       0                1
# 24                       0                0
# 25                       0                1
# 26                       0                0
# 28                       0                0
# 31                       0                0
# 34                       0                0
# 35                       0                0
# 36                       0                0
# 38                       0                0
# 39                       0                1
# ...                    ...              ...
# 1273                     0                0
# 1275                     0                0
# 1277                     0                1
# 1278                     0                0
# 1279                     0                0
# 1280                     0                0
# 1281                     1                0
# 1282                     0                0
# 1283                     0                0
# 1284                     1                0
# 1285                     0                0
# 1286                     0                0
# 1287                     0                0
# 1288                     0                0
# 1289                     0                0
# 1290                     0                0
# 1291                     0                0
# 1292                     0                1
# 1293                     0                0
# 1294                     0                1
# 1295                     0                0
# 1296                     0                0
# 1297                     0                0
# 1298                     0                0
# 1299                     0                0
# 1301                     0                1
# 1303                     0                0
# 1304                     0                1
# 1306                     0                0
# 1307                     0                0
#
# [1046 rows x 12 columns]

# %% [markdown]
# ### Importar modelo regressivo

# %%
from sklearn import linear_model

# %% [markdown]
# ### Instanciar modelo

# %%
lm = linear_model.LinearRegression()

# %% [markdown]
# ### Importar train_test_split para preparar para treino

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Dividir 70% para treinar, 30% para testar

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

# %% [markdown]
# ### Treinar modelo

# %%
X_train.shape, y_train.shape
# Out:
# ((732, 12), (732,))

# %%
X_test.shape, y_test.shape
# Out:
# ((314, 12), (314,))

# %%
lm.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %% [markdown]
# ### Fazer predição

# %%
predicao = lm.predict(X_test)
predicao.shape
# Out:
# (314,)

# %% [markdown]
# ### Importar mean_squared_error (erro quadrado médio)

# %%
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ### Averiguar score

# %%
lm.score(X_test, y_test)
# Out:
# 0.43470319135239244

# %% [markdown]
# ### Averiguar rmse

# %%
mse = mean_squared_error(y_test, predicao)

# %%
rmse = np.sqrt(mse)

# %%
rmse
# Out:
# 10.226405610903221

# %% [markdown]
# ### Visualizar resíduos em scatterplot

# %%
plt.scatter(y_test, predicao)
plt.show()

# %% [markdown]
# <a name="tarifa"></a>

# %% [markdown]
# ### Aplicar modelo nos dados nulos

# %% [markdown]
# ### Criar coluna Idade contendos as predições

# %% [markdown]
# ### Averiguar shapes

# %% [markdown]
# ### Concatenar dados

# %% [markdown]
# ### Criar DataFrame contendo "IdPassageiro" e "Idade"

# %% [markdown]
# ### Salvar CSV com idade completa
